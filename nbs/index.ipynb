# %%
#| hide
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # dataverse_visualize
#
# >

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install dataverse_visualize in Development mode

# %% [markdown]
# ```sh
# # make sure dataverse_visualize package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to dataverse_visualize
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/nakamura196/dataverse_visualize.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c nakamura196 dataverse_visualize
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install dataverse_visualize
# ```
#
#
# [repo]: https://github.com/nakamura196/dataverse_visualize
# [docs]: https://nakamura196.github.io/dataverse_visualize/
# [pypi]: https://pypi.org/project/dataverse_visualize/
# [conda]: https://anaconda.org/nakamura196/dataverse_visualize

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/nakamura196/dataverse_visualize
# [docs]: https://nakamura196.github.io/dataverse_visualize/
# [pypi]: https://pypi.org/project/dataverse_visualize/
# [conda]: https://anaconda.org/nakamura196/dataverse_visualize

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
from dataverse_visualize.core import CoreClient

url = "https://borealisdata.ca"

client = CoreClient(url)

client.visualize_data()
